# %% [markdown]
# ## Test
# ___

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.random.normal(loc=0, scale=1, size=100)

# minmax
x = (x-np.min(x))/(np.max(x)-np.min(x))

sns.set_style('darkgrid')

sns.histplot(x=x, bins=20, kde=True)
plt.show()

# %%
x
# Out:
# array([0.46148559, 0.19069187, 0.57492084, 0.82551284, 0.34630113,
#        0.67223928, 0.19560637, 0.1388103 , 0.02577881, 0.7847594 ,
#        0.12507693, 0.38376775, 0.42080572, 0.03209747, 0.45067429,
#        0.49334377, 0.62555062, 0.45746853, 0.42701065, 0.32032166,
#        0.58461378, 0.66279513, 0.51846273, 0.48154462, 0.07386361,
#        0.88140086, 0.4196689 , 0.55727865, 0.45157715, 0.30419705,
#        0.21853827, 0.70803704, 0.760901  , 0.76749561, 0.48225816,
#        0.        , 0.69479237, 0.89528003, 0.55347571, 0.35114239,
#        0.41034449, 0.3330974 , 0.40987211, 0.64137252, 0.57219015,
#        0.3870036 , 0.33833672, 0.604576  , 0.27125471, 0.50830044,
#        0.43030845, 0.93320138, 0.46900367, 0.23964451, 0.38742348,
#        0.58398731, 0.5551384 , 0.5473417 , 0.42010357, 0.52595254,
#        0.66185143, 0.16347591, 0.39566596, 0.46195973, 0.38651762,
#        0.35113805, 1.        , 0.81117004, 0.53667059, 0.29324453,
#        0.34511578, 0.739211  , 0.70221767, 0.53208649, 0.25082969,
#        0.12169959, 0.67177375, 0.77228191, 0.42711381, 0.34171736,
#        0.5434071 , 0.49174574, 0.20696557, 0.43272902, 0.51848836,
#        0.3557965 , 0.07157938, 0.40392529, 0.36084854, 0.81820459,
#        0.71425611, 0.45033659, 0.72421547, 0.62552307, 0.19359781,
#        0.58750488, 0.22811878, 0.53645189, 0.41087767, 0.59769916])

# %%
cells = np.zeros(20)

n = len(x)
for i in range(n):
    cells[np.argmin(cells)] += x[i]

cells *= len(cells)/n

cells
# Out:
# array([0.52023212, 0.45128291, 0.42499117, 0.54181123, 0.50381962,
#        0.4601238 , 0.51404004, 0.43323705, 0.42781542, 0.42570928,
#        0.43039145, 0.50759865, 0.52264444, 0.42457409, 0.45149006,
#        0.4712168 , 0.51781267, 0.44957519, 0.52302074, 0.42381576])
